# %% [markdown]
# # Intelligent Editor Environment (in Auszügen)
# ## Simulation und Modellierung WS19/20: Textstatistik
# ### Marvin Beese, 786300, marvin.beese@uni-potsdam.de

# %% [markdown]
# ##### Nutzungshinweise
# Zu beachten ist, dass die Textdatei _Die Leiden des jungen Werthers.txt_ im Heimverzeichnis im Desktop-Verzeichnis gespeichert werden muss.

# %%
import re
import os
import string
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg, NavigationToolbar2Tk
# %matplotlib notebook

# %% [markdown]
# #### Statistische Analyse der Wörter in einem Text
# Funktion _L=splitstring(s)_
#
# mit String _s_, Liste _L_

# %%
"""gets words from input string and returns List of words"""
def splitstring(textInput):
    wordList = re.split(r'[\.\,\;\s\:\"\!\?]\s*', str(textInput))
    return wordList

# %% [markdown]
# #### Einlesen einer Datei und Identifizierung der einzelnen Wörter im Text
# Funktion _n,W = textStats(file, ReturnDict=False)_
#
# mit Integer _n_, Wörterbuch _W_, Textdatei _file_, boolean _ReturnDict_

# %%
"""input file to count including words,
        returns number or Words, Dictionary(key: string word, value: int occurrences)"""
def textStats(file, ReturnDict=False):
    # read file and save input in List
    print(file)
    f= open(file, mode='r')
    fileContent = f.read()
    currWordList = splitstring(fileContent)
    # count words
    wordDict={};fullwordList=[]; upperWords=[]
    if(ReturnDict==True):
        for word in currWordList:
            if word.isalpha():
                fullwordList.append(word)
                # only get Eigennamen and Nomen through firstly checking all lowercase words and checking the remaining upper case letters afterwards
                if(word[0].isupper()):
                    upperWords.append(word)
                    continue
                # increment when already found in text
                if word.casefold() in wordDict:
                    wordDict[word.casefold()]+=1
                else:
                    wordDict[word]=1
            # special case: apostrophe in word
            elif "\'" in word:
                fullwordList.append(word)
                if word.casefold() in wordDict:
                    wordDict[word.casefold()]+=1
                else:
                    wordDict[word]=1
        for word in upperWords:
            if word.casefold() in wordDict:
                wordDict[word.casefold()]+=1
            elif word in wordDict:
                wordDict[word]+=1
            else:
                wordDict[word]=1
    wordOccurrences = len(fullwordList)
    return wordOccurrences, wordDict

# %%
globalPath = os.path.normpath(os.path.join(os.environ["HOMEPATH"], "Desktop"))
file = os.path.normpath(os.path.join(globalPath, 'Die Leiden des jungen Werthers.txt'))
print(file)
anzahl, woerterbuch = textStats(file,True)
print(anzahl, woerterbuch)
# Out:
# \Users\beese\Desktop\Die Leiden des jungen Werthers.txt
# \Users\beese\Desktop\Die Leiden des jungen Werthers.txt
# 35926 {'froh': 2, 'bin': 68, 'ich': 1121, 'daÃŸ': 1, 'weg': 24, 'was': 153, 'ist': 368, 'das': 515, 'des': 168, 'zu': 572, 'verlassen': 13, 'den': 381, 'so': 357, 'liebe': 47, 'von': 270, 'dem': 328, 'unzertrennlich': 1, 'war': 207, 'und': 1405, 'sein': 162, 'weiÃŸ': 1, 'du': 219, 'verzeihst': 1, "mir's": 28, 'nicht': 453, 'meine': 126, 'recht': 27, 'ausgesucht': 1, 'vom': 52, 'um': 159, 'ein': 294, 'wie': 314, 'arme': 12, 'doch': 82, 'unschuldig': 3, "Konnt'": 1, 'die': 904, 'eigensinnigen': 1, 'ihrer': 45, 'mir': 348, 'eine': 170, 'angenehme': 2, 'verschafften': 1, 'in': 489, 'armen': 14, 'sich': 312, 'bildete': 1, 'ganz': 63, "Hab'": 1, 'ihre': 113, 'mich': 361, 'an': 228, 'wahren': 9, 'der': 789, 'uns': 85, 'oft': 56, 'lachen': 5, 'machten': 4, 'wenig': 18, 'sie': 755, 'waren': 38, 'selbst': 64, 'ergetzt': 1, 'er': 441, 'klagen': 3, 'darf': 10, 'will': 59, 'lieber': 36, 'verspreche': 2, "dir's": 2, 'bessern': 1, 'mehr': 62, 'biÃŸchen': 1, 'vorlegt': 1, "ich's": 12, 'immer': 60, 'getan': 7, 'habe': 141, 'genieÃŸen': 1, 'soll': 43, 'vergangen': 1, 'hast': 29, 'minder': 2, 'unter': 60, 'wenn': 213, 'warum': 41, 'gemacht': 24, 'sind': 78, 'viel': 59, 'vergangenen': 3, 'eher': 5, 'als': 193, 'ertragen': 3, 'bist': 15, 'gut': 31, 'meiner': 57, 'sagen': 49, 'ihr': 233, 'bestens': 1, 'betreiben': 1, 'ehstens': 2, 'davon': 20, 'geben': 16, 'werde': 29, 'gesprochen': 7, 'bei': 67, 'weitem': 2, 'gefunden': 13, 'man': 90, 'aus': 115, 'macht': 20, 'muntere': 2, 'heftige': 1, 'besten': 4, 'sagte': 106, 'welchen': 2, 'bereit': 2, 'alles': 116, 'herauszugeben': 1, 'wir': 133, 'mag': 13, 'jetzt': 30, 'nichts': 70, 'schreiben': 11, 'sage': 14, 'es': 328, 'gehen': 27, 'mein': 125, 'wieder': 89, 'diesem': 15, 'kleinen': 28, 'vielleicht': 15, 'machen': 44, 'beiden': 5, 'letzteren': 1, 'gewiÃŸ': 1, 'seltener': 1, 'befinde': 3, 'hier': 62, 'gar': 32, 'wohl': 76, 'meinem': 52, 'dieser': 36, 'paradiesischen': 1, 'diese': 57, 'mit': 367, 'aller': 27, 'schauderndes': 1, 'jede': 4, 'zum': 58, 'werden': 59, 'herumschweben': 1, 'alle': 65, 'seine': 75, 'darin': 10, 'finden': 19, 'unangenehm': 1, 'dagegen': 4, 'rings': 14, 'umher': 12, 'unaussprechliche': 1, 'bewog': 1, 'verstorbenen': 2, 'einen': 134, 'auf': 286, 'einem': 105, 'anzulegen': 1, 'kreuzen': 1, 'lieblichsten': 2, 'bilden': 2, 'einfach': 3, 'gleich': 31, 'wissenschaftlicher': 1, 'sondern': 5, 'gezeichnet': 2, 'seiner': 68, 'wollte': 41, 'manche': 7, "hab'": 12, 'verfallenen': 1, 'geweint': 1, 'auch': 115, 'meines': 18, 'zugetan': 3, 'nur': 91, 'seit': 16, 'paar': 10, 'wird': 66, 'dabei': 10, 'befinden': 2, 'wunderbare': 3, 'hat': 107, 'ganze': 27, 'eingenommen': 3, 'ganzem': 5, 'genieÃŸe': 1, 'allein': 34, 'freue': 1, 'solche': 2, 'geschaffen': 1, 'ruhigem': 2, 'versunken': 2, 'darunter': 2, 'leidet': 2, 'zeichnen': 3, 'nie': 29, 'gewesen': 24, 'diesen': 25, 'dampft': 1, 'hohe': 4, 'undurchdringlichen': 1, 'ruht': 5, 'einzelne': 2, 'innere': 5, 'stehlen': 1, 'dann': 41, 'im': 104, 'hohen': 11, 'am': 129, 'fallenden': 1, 'liege': 2, 'tausend': 19, 'mannigfaltige': 3, 'zwischen': 20, 'nach': 136, 'seinem': 34, 'schuf': 3, 'ewiger': 2, 'schwebend': 1, "Wenn's": 1, 'her': 23, 'ruhn': 2, 'einer': 87, 'sehne': 1, 'denke': 11, 'ach': 45, 'einhauchen': 1, 'voll': 13, 'warm': 2, 'dir': 74, 'lebt': 6, 'deiner': 12, 'deine': 18, 'unendlichen': 8, 'gehe': 16, 'zugrunde': 9, 'erliege': 1, 'ob': 28, 'schweben': 3, 'oder': 34, 'warme': 5, 'himmlische': 3, 'paradiesisch': 1, 'vor': 108, 'gebannt': 2, 'ihren': 44, 'gehst': 3, 'hinunter': 4, 'findest': 2, 'dich': 62, 'da': 165, 'zwanzig': 1, 'hinabgehen': 1, 'wo': 40, 'unten': 5, 'klarste': 1, 'quillt': 1, 'kleine': 16, 'oben': 2, 'bedecken': 2, 'vergeht': 1, 'kein': 33, 'sitze': 8, 'kommen': 32, 'holen': 5, 'harmloseste': 2, 'ehemals': 3, 'verrichteten': 1, 'patriarchalische': 1, 'lebhaft': 8, 'freien': 2, 'muÃŸ': 1, 'schweren': 3, 'gelabt': 2, 'haben': 61, 'mitempfinden': 2, 'kann': 73, 'fragst': 2, 'schicken': 1, 'sollst': 4, 'bitte': 24, 'willen': 14, 'la ...

# %% [markdown]
# #### Top-100 Wörter in der Datei
#
# Sortieren des Wörterbuches mittels: _L=sortTextStats(List)_
#
# mit Liste _L_, _List_
#
# Erstellen einer __Tabelle__ mit den 100 höchsten Werten mittels: _table, Substantive=buildTable(sortedList)_
#
# mit String _table,_ _Substantive_ und Liste _sortedList_

# %%
"""sorts a list starting with the highest number of occurrences using lambda expression"""
def sortTextStats(List):
    return sorted(List.items(), key=lambda x: x[1], reverse=True)

"""builds a table for the first 100 entries of the sorted Dictionary sortedList"""
def buildTable(sortedList):
    # get values
    limit=100
    i = 0
    outputTxt=""; upperWords=""
    for k, v in sortedList:
        if (i >= limit):
            break
        i = i + 1
        outputTxt += "{0}:\t{1}\t{2}\n".format(i, k, v)
        if(str(k)[0].isupper()):
            upperWords += " {0}".format(str(k))
    return outputTxt, upperWords

# %%
sortiertDict = sortTextStats(woerterbuch)
table, Substantives = buildTable(sortiertDict)
print(table)
print("Substantive: {0}".format(Substantives))
# Out:
# 1:	und	1405
# 2:	ich	1121
# 3:	die	904
# 4:	der	789
# 5:	sie	755
# 6:	zu	572
# 7:	das	515
# 8:	in	489
# 9:	nicht	453
# 10:	er	441
# 11:	den	381
# 12:	ist	368
# 13:	mit	367
# 14:	mich	361
# 15:	so	357
# 16:	mir	348
# 17:	dem	328
# 18:	es	328
# 19:	wie	314
# 20:	sich	312
# 21:	ein	294
# 22:	auf	286
# 23:	von	270
# 24:	ihr	233
# 25:	an	228
# 26:	du	219
# 27:	wenn	213
# 28:	war	207
# 29:	als	193
# 30:	eine	170
# 31:	des	168
# 32:	da	165
# 33:	sein	162
# 34:	um	159
# 35:	was	153
# 36:	habe	141
# 37:	nach	136
# 38:	einen	134
# 39:	wir	133
# 40:	ihm	131
# 41:	am	129
# 42:	ihn	127
# 43:	meine	126
# 44:	mein	125
# 45:	noch	118
# 46:	alles	116
# 47:	aus	115
# 48:	auch	115
# 49:	ihre	113
# 50:	vor	108
# 51:	hat	107
# 52:	sagte	106
# 53:	einem	105
# 54:	im	104
# 55:	nur	91
# 56:	man	90
# 57:	wieder	89
# 58:	einer	87
# 59:	hatte	86
# 60:	uns	85
# 61:	doch	82
# 62:	sind	78
# 63:	wohl	76
# 64:	seine	75
# 65:	dir	74
# 66:	aber	74
# 67:	kann	73
# 68:	nun	73
# 69:	Seele	72
# 70:	nichts	70
# 71:	denn	70
# 72:	bin	68
# 73:	seiner	68
# 74:	Lotte	68
# 75:	bei	67
# 76:	wird	66
# 77:	alle	65
# 78:	selbst	64
# 79:	ganz	63
# 80:	mehr	62
# 81:	hier	62
# 82:	dich	62
# 83:	Herz	62
# 84:	haben	61
# 85:	Menschen	61
# 86:	immer	60
# 87:	unter	60
# 88:	o	60
# 89:	will	59
# 90:	viel	59
# 91:	werden	59
# 92:	zum	58
# 93:	meiner	57
# 94:	diese	57
# 95:	seinen	57
# 96:	oft	56
# 97:	durch	56
# 98:	Albert	56
# 99:	vom	52
# 100:	meinem	52
#
# Substantive:  Seele Lotte Herz Menschen Albert

# %% [markdown]
# #### Plotten der Wörter über den Rang auf einer doppelt logarithmischen Skala
#
# Berechnen der Plot-Daten mittels _x,y,word = calcPlot(limit, sortedDict)_ und mit _buildPlot(limit, sortedDict)_
#
# mit np.array _x, y, word, _ integer _limit_ und dictionary _sortedDict_

# %%
"""calc plot with defined word-limit. Rank (i), Occurrences (v) and Word (k) are used"""
def calcPlot(limit, sortedDict):
    x=np.array([])
    y=np.array([])
    word=np.array([])
    i = 0
    for k,v in sortedDict:
        if (i >= limit):
            break
        i+=1
        x= np.append(x,i)
        y=np.append(y,v)
        word= np.append(word, k)
    return x,y,word

def buildPlot(limit, x, y, word):
    # get values
    x = np.asarray(x); y = np.asarray(y); word=np.asarray(word)
    a= plt.scatter(x, y, c='red')

    for i, txt in enumerate(word):
        a = plt.annotate(txt, (i + 1, y[i]), xycoords='data')

    a = plt.title("Most frequent Words", fontsize=16)
    a = plt.ylabel("Occurrences", fontsize=9)
    a = plt.xlabel("Word Rank", fontsize=9)
    a = plt.grid(True)
#     a.tick_params(labelsize=8)
    a= plt.xscale(value='log')
    a= plt.yscale(value='log')
    return a

# %%
x,y,word = calcPlot(100,sortiertDict)
buildPlot(100, x,y,word)

# %% [markdown]
# #### Berechnung und Darstellung der Steigung der Geraden durch die gegebenen Punkte
#
# Berechnung der Steigung der Geraden mittels linearer Regressionsanalyse über die Top-100 Wörter mit _slope=linRegSlope(xArr, yArr, max), calcXMedian(xArr, max), calcYMedian(yArr, max), calcSxx(xArr, xMed, max), calcSxy(xArr,yArr,xMed,yMed,max)_
#
# Hierbei ist _xMed_ und _yMed_ das Median über die gegebenen x- bzw. y-Werte, $Sxx = \sum_{i=0}^{n=max-1}({x_i - x_{Med}})^2$, $Sxy= \sum_{i=0}^{n=max-1}({x_i - x_{Med}})*({y_i - y_{Med}})$ und $slope= \frac{Sxy}{Sxx}$
#
# Darstellung der Steigung der Verteilung der Top-100-Wörter auf einer log-log-Skala mittels _drawSlope(slope, x, y, size)_

# %%
# (\sum_{i=0}^{n=max-1}{x_i})/n
def calcXMedian(xArr, max):
    xSum=0
    for i in range(max):
        xSum+=xArr[i]
    xMedian=xSum/max
    print("\txMedian: ", xMedian)
    return xMedian

# (\sum_{i=0}^{n=max-1}{y_i})/n
def calcYMedian(yArr, max):
    ySum=0
    for i in range(max):
        ySum+=yArr[i]
    yMedian=ySum/max
    print("\tyMedian: ",yMedian)
    return yMedian

"calculates the average square of deviation"
# \sum_{i=0}^{n=max-1}{x_i - xMed}^2
def calcSxx(xArr, xMed, max):
    Sxx=0
    for i in range(max):
        Sxx+= (xArr[i]-xMed)**2
    print("\tSxx: ",Sxx)
    return Sxx

"calculates the product of the x- and y-Deviation"
# \sum_{i=0}^{n=max-1}{x_i - xMed}*{y_i - yMed}
def calcSxy(xArr, yArr, xMed, yMed, max):
    Sxy=0
    for i in range(max):
        Sxy+=(xArr[i]-xMed)*(yArr[i]-yMed)
    print("\tSxy: ",Sxy)
    return Sxy

"calculates Slope of Distribution using linear Regression"
# \frac{Sxy}{Sxx}
def linRegSlope(xArr, yArr, max):
    xMed = calcXMedian(xArr, max)
    yMed = calcYMedian(yArr, max)
    Sxy = calcSxy(xArr, yArr, xMed, yMed, max)
    Sxx = calcSxx(xArr, xMed, max)
    slope = Sxy / Sxx
    print("slope: ", slope)
    print("\t{0}/{1}={2}".format(Sxy, Sxx, slope))
    return slope

def drawSlope(slope, x, y, size):
    # get values
    startx = x[0]
    endx = x[-1:]
    starty = y[0] 
    endy = starty+x[size-1]*slope
    # plot graph
    b = plt.plot([startx, endx],[starty,endy], c='blue')
    b = plt.title("Most frequent Words", fontsize=16)
    b = plt.ylabel("Occurrences", fontsize=9)
    b = plt.xlabel("Word Rank", fontsize=9)
    b = plt.grid(True)
    b= plt.xscale(value='log')
    b= plt.yscale(value='log')
    b = plt.scatter(x, y, c='red')
    for i, txt in enumerate(word):
        b = plt.annotate(txt, (i + 1, y[i]), xycoords='data')

# %%
slope = linRegSlope(x,y,x.size)
drawSlope(slope, x, y, x.size)
# Out:
# 	xMedian:  50.5
# 	yMedian:  194.19
# 	Sxy:  -474342.5000000002
# 	Sxx:  83325.0
# slope:  -5.692679267926795
# 	-474342.5000000002/83325.0=-5.692679267926795

# %% [markdown]
# #### Berechnung des Exponentens der Zipf-Verteilung
#
# Berechnung des Exponentens mittels _exp = exponentZipf(xArr, yArr, max)._
#
# Hierbei wird die Funktion _linRegSlope_ aufgerufen.
#
# Es gilt $exp= 1+ \frac{1}{|m|}$ .

# %%
"calculates the exponent of the Distribution"
# exp= 1+ \frac{1}{|m|} //m = linRegSlope() //Exponent der Verteilungsfunktion
def exponentZipf(xArr, yArr, max):
    m = linRegSlope(xArr, yArr, max)
    exp = 1+ (1/ abs(m))
    print("expZipf: ",exp)
    print("\t1+(1/{0}) = {1}".format(abs(m),exp))
    return exp

# %%
exponentZipf(x,y,x.size)
# Out:
# 	xMedian:  50.5
# 	yMedian:  194.19
# 	Sxy:  -474342.5000000002
# 	Sxx:  83325.0
# slope:  -5.692679267926795
# 	-474342.5000000002/83325.0=-5.692679267926795
# expZipf:  1.1756642088786056
# 	1+(1/5.692679267926795) = 1.1756642088786056
# 1.1756642088786056

# %% [markdown]
# #### Generierung von Zufallstexten in einer Textdatei
# ##### Von Affen und Schreibmaschinen
#
# Hierbei ist die Wahrscheinlichkeit _p = splitterProbability_ für Leer- oder Satzzeichen und die Wahrscheinlichkeit _1-p = letterProbability_ für beliebige Buchstaben des deutschen Alphabets.
# Periodisch wiederkommende Zeilenumbrüche treten nach _n = lineBreak_ Zeichen auf.
# Die Anzahl der Zeichen einer Datei wird mit _size_ festgelegt.
#
# Es werden die Funktionen _randomLetter(),_ _randomSplitter(),_ _randomTextGeneration(letterProbability, lineBreakNr, size)_ und _randomTextFile(letterProbability, lineBreakNr, size)_ verwendet.

# %%
"""creates randomly a letter of the eng/ger alphabet"""
def randomLetter():
    alphabetList = np.array(list(string.ascii_letters))
    germanLetters = np.array(['ä', 'ö', 'ü', 'Ä', 'Ö', 'Ü', 'ß'])
    alphabetList= np.concatenate((alphabetList, germanLetters), axis=None)
    letter = np.random.choice(alphabetList)
    return letter

"""creates randomly a space or punctuation"""
def randomSplitter():
    splitSymb = np.array([' ',',','.',';',':','!','?']) #[\.\,\;\s\:\"\!\?]
    splitter = np.random.choice(splitSymb)
    return splitter

"""creates words and splitter depending on respective probability of given size. 
    Linebreaks are included after a given number of elements"""
def randomTextGeneration(letterProb, linebreakNr, size):
    # Probabilities
    letterProbability = letterProb
    splitterProbability = 1-letterProbability
    linebreak = linebreakNr

    randomText=""
    for step in range (1,size+1):
        if(step%linebreak==0):
            randomText+="\n"
        else:
            letter=randomLetter()
            splitter=randomSplitter()
            choosenChar= np.random.choice([letter,splitter],1,p=[letterProbability, splitterProbability])
            randomText+=choosenChar[0]
    randomText = str(randomText)
    print(randomText)
    return randomText

"""invokes randomTextGeneration() and writes the text into the text RandomText.txt"""
def randomTextFile(letterProb, linebreakNr, size):
    randomText = randomTextGeneration(letterProb, linebreakNr, size)
    globalPath = os.path.normpath(os.path.join(os.environ["HOMEPATH"], "Desktop"))
    filename = os.path.normpath(os.path.join(globalPath, 'RandomText.txt'))
    file = open(filename, 'w')
    file.write(randomText)
    file.close()
    print("File {0} was saved".format(filename))
    return file.name

# %%
randomFile = randomTextFile(0.8, 50, 2000)
# Out:
# VwIDl.Y?wouP,duuL,Z:wjWÄj,YvqLlv:!DLÄKU:ö qxtXIpJ
# xGVtÖSaüOysBDb n,V!QCJuGfDvpStfEXn Kv:oP.Wcn .tZQ
# zIIvAy!Vg;?ßlFfyLzä!ÄYLßyEWHiQ yqE!,DTbEIgjHhSvCi
# Iat. ?Bp?r!JöQN.BL;ä;;yBDlYf,öÄX ßüp?mfdW?äYejßqö
#  hH.?cC?H,:k,Tfy,fR lÜWzadOiq!CF!.vpvONZ,ypTKZ;bß
# qmOM.äQORsLiPJV.ÄQAhMM!:afADFrGnH;.Ün!üaPHJüsx:ep
# ?uotONN,CengkTzDjCFpjoSBöcpxXLgR;yRkUä!Rr:XQqyÄmH
# :qc?eKSAAn,JxL;r CB:whuCÜjxpoCca;ZbgdHQ?ÜzmsfTnDT
# G?JL;,OD;äsüN?euE!yiPY.:WaQj;PÖÜeuosh!UD;k !Zmt,U
# DxSJörY:TUFpg?GGPÜsCeXN,u .! zRuYKw?XBXbZj .övßZü
# q QjPäuz YÄrAeJQväü CRew;fxüFÜEXGKrR!HuÜh,p.:tnXe
# vSWqSö;EqPqA,KMÜTazÜL:K?!Üjüv?BÜ:;äPiÄJ!LhuÖHg;LO
# iDDaL !HHOU,qnCPHaiTFnyu.VsÜKrbZ.xt!dc.MJvhJhfvnd
# .C!:üAiFx;xs;hütjVjYO,IWc!YjpdiGÜTjcJxt d:!üM!jsS
# YXKjQFVZ ;. hxt,ßüqEoxcfriniZZß,ImN;vTc!eäTOß?E;Ö
# ?bCazLWr,;;BCwOp UWOQ.NULÄJlR EAR,QORN VyQynz.ÄJ:
# WßG..;v,uLfäFäcEPJwnbe?ltÖwtcXßOioEG ,:OwT;!hIItq
# phLlFwHKäjoaW?ÖNEw,y!OovwRh dgqzxCQBcd ,jCükNÖxB,
# MsNXN:qÜXc.MRV!I;::.ü .QvR.LwLPßföFriU:zÄz!XYüteü
# U;ÖjfYÖRßOgZxwo!HHCdBSKöXÜSAAa OBMB.uAMQIo;fzBöNw
# StVü; :?,GFIöEuvgäBgVHk:qCXFd?FM.?OoPÖQü,HEüpQÄJZ
# ZrRxybrUUo.CäA?stÄtÖÜD.?päeßlr,;ATd:HPsoV??;EEHgl
# .AöBP;ShjUaÄQgVvnöeW nAuFÜvrfeMßwpQSC,TRbv;ÜwW,LJ
# reÄk?ßFsFS.pUfppMVJe qE;T tjrH;ÖÜeZTo u;o;ZAÜh!CI
# Ö.XIÜ.NdWluXptAyikeqr!!do?YÖUV..bSo,U!?uZVBQrA  !
# tgp:IYvädäJu.xh:.ss,NyäoüÄVOPx.:AW.KmÜPäbyOu f,D,
# ?dnB,?JvINWURCfo?QÖ:DnVvößxO rmW?Ftm:Iä:LiVjHhTTo
# s:NaeY ws AIygD ödÖ CkWsD,FIXär, efOqÄV WNmEbmnNt
# IHiXc,tkäjEuÄeDÄNzslWÄWbE!c.e?F?ÖVKIQ!? YbzpJÄbOi
# mDF.AZXm.? x:cEM:sOW.Fp?bzQ.XkHs,t?p;uERYyoiüü!A:
# bTcCedFrÄn:, QGßRaw:g?FMWÖ!dtzSg YMYMcRbCy! lVlZq
# yhPv;cGeIbR?E!ßTpDöÄYLr,X;yQqr Y,BVn.cgUÖljE,X:ßd
# QqucOX?rqwZt?ozfm y M.D;vßüSk.zÜ. JwÄvÜgUiÄmMßTu
# WkoÜWh. pEX!GEJMAbMNUKSm;ÖKGrhbZ?n?TxywWPOE.MQ!Zy
# CBWx!wk AQÖEÄ;zVGH,E,f;,fyhMCÜüzüÄss!iüd:ZYoIMRT.
# ößI?O!JeßBdDbqVÖGHÜp.reV.RR UD:XäüJoxWuJOiU?KW !B
# jdFöMVmTMYW:raI uJT:P,BeäFtpJprGYB.ZO:RÜö YMyx?y:
# mo!Bheg DAXvEMS?.öaxk;y?RBDhO!GIisVk.l:X NV:byäY?
# ,ÜPüz?äPwu;F.gHn ZhGmVjdNÄäc?QKuI c,:,qU!b.fKYPSx
# M: exMNli?öÄqr:Ä;:B!FrukÜsQSxFeEii,yöAe?YI;wÖwr.;
#
# File \Users\beese\Desktop\RandomText.txt was saved

# %% [markdown]
# #### Statistische Auswertung der Zufalls-Datei _RandomText.txt_

# %%
print(randomFile)
# textStats
print("---Text Stats---")
anzahlRandom, woerterbuchRandom = textStats(randomFile,True)
print(anzahlRandom, woerterbuchRandom)
# sort text stats
sortiertDictRandom = sortTextStats(woerterbuchRandom)
tableRandom, SubstantivesRandom = buildTable(sortiertDictRandom)
print("---Table---")
print(tableRandom)
print("Substantive: {0}".format(SubstantivesRandom))
# plot data
xRand,yRand,wordRand = calcPlot(100,sortiertDictRandom)
buildPlot(100, xRand,yRand,wordRand)
# calculate and plot slope
print("---Slope---")
slopeRand = linRegSlope(xRand,yRand,xRand.size)
drawSlope(slopeRand, xRand, yRand, xRand.size)
# calculate exponent of zipf distribution
print("---Exponent of Zipf Distribution")
exponentZipf(xRand,yRand,xRand.size)
# Out:
# \Users\beese\Desktop\RandomText.txt
# ---Text Stats---
# \Users\beese\Desktop\RandomText.txt
# 336 {'wouP': 1, 'duuL': 1, 'wjWÄj': 1, 'ö': 3, 'qxtXIpJ': 1, 'xGVtÖSaüOysBDb': 1, 'n': 2, 'oP': 1, 'tZQ': 1, 'zIIvAy': 1, 'ßlFfyLzä': 1, 'yqE': 1, 'r': 2, 'ä': 2, 'yBDlYf': 1, 'öÄX': 1, 'ßüp': 1, 'mfdW': 1, 'äYejßqö': 1, 'hH': 1, 'cC': 1, 'k': 3, 'fR': 1, 'lÜWzadOiq': 1, 'vpvONZ': 1, 'ypTKZ': 1, 'bß': 1, 'qmOM': 1, 'äQORsLiPJV': 1, 'afADFrGnH': 1, 'üaPHJüsx': 1, 'ep': 1, 'uotONN': 1, 'yRkUä': 1, 'qc': 1, 'eKSAAn': 1, 'whuCÜjxpoCca': 1, 'äsüN': 1, 'euE': 1, 'yiPY': 1, 'u': 5, 'zRuYKw': 1, 'övßZü': 1, 'q': 1, 'fxüFÜEXGKrR': 1, 'p': 3, 'tnXe': 1, 'vSWqSö': 1, 'äPiÄJ': 1, 'iDDaL': 1, 'qnCPHaiTFnyu': 1, 'xt': 1, 'dc': 1, 'üAiFx': 1, 'xs': 1, 'hütjVjYO': 1, 'd': 3, 'üM': 1, 'jsS': 1, 'hxt': 1, 'ßüqEoxcfriniZZß': 1, 'vTc': 1, 'eäTOß': 1, 'bCazLWr': 1, 'v': 2, 'uLfäFäcEPJwnbe': 1, 'ltÖwtcXßOioEG': 1, 'hIItq': 1, 'phLlFwHKäjoaW': 1, 'y': 6, 'dgqzxCQBcd': 1, 'jCükNÖxB': 1, 'qÜXc': 1, 'ü': 1, 'zÄz': 1, 'uAMQIo': 1, 'fzBöNw': 1, 'qCXFd': 1, 'stÄtÖÜD': 1, 'päeßlr': 1, 'nAuFÜvrfeMßwpQSC': 1, 'reÄk': 1, 'ßFsFS': 1, 'pUfppMVJe': 1, 'qE': 1, 'tjrH': 1, 'o': 2, 'do': 1, 'bSo': 1, 'uZVBQrA': 1, 'tgp': 1, 'xh': 1, 'ss': 1, 'f': 4, 'dnB': 1, 'rmW': 1, 's': 1, 'ws': 1, 'ödÖ': 1, 'efOqÄV': 1, 'tkäjEuÄeDÄNzslWÄWbE': 1, 'c': 3, 'e': 4, 'mDF': 1, 'x': 4, 'cEM': 1, 'sOW': 1, 'bzQ': 1, 't': 2, 'uERYyoiüü': 1, 'bTcCedFrÄn': 1, 'g': 2, 'dtzSg': 1, 'lVlZq': 1, 'yhPv': 1, 'cGeIbR': 1, 'ßTpDöÄYLr': 1, 'yQqr': 1, 'cgUÖljE': 1, 'ßd': 1, 'rqwZt': 1, 'ozfm': 1, 'vßüSk': 1, 'zÜ': 1, 'pEX': 1, 'wk': 1, 'zVGH': 1, 'fyhMCÜüzüÄss': 1, 'iüd': 1, 'ößI': 1, 'reV': 1, 'jdFöMVmTMYW': 1, 'raI': 1, 'uJT': 1, 'mo': 1, 'öaxk': 1, 'l': 1, 'byäY': 1, 'äPwu': 1, 'gHn': 1, 'qU': 1, 'b': 3, 'fKYPSx': 1, 'exMNli': 1, 'öÄqr': 1, 'yöAe': 1, 'wÖwr': 1, 'VwIDl': 1, 'Z': 1, 'YvqLlv': 1, 'DLÄKU': 1, 'QCJuGfDvpStfEXn': 1, 'Kv': 1, 'Wcn': 1, 'Vg': 1, 'ÄYLßyEWHiQ': 1, 'DTbEIgjHhSvCi': 1, 'Iat': 1, 'Bp': 1, 'JöQN': 1, 'BL': 1, 'H': 1, 'Tfy': 1, 'CF': 1, 'ÄQAhMM': 1, 'Ün': 1, 'CengkTzDjCFpjoSBöcpxXLgR': 1, 'Rr': 1, 'XQqyÄmH': 1, 'JxL': 1, 'CB': 1, 'ZbgdHQ': 1, 'ÜzmsfTnDT': 1, 'JL': 1, 'OD': 1, 'WaQj': 1, 'PÖÜeuosh': 1, 'UD': 2, 'Zmt': 1, 'DxSJörY': 1, 'TUFpg': 1, 'GGPÜsCeXN': 1, 'XBXbZj': 1, 'QjPäuz': 1, 'YÄrAeJQväü': 1, 'CRew': 1, 'HuÜh': 1, 'EqPqA': 1, 'KMÜTazÜL': 1, 'Üjüv': 1, 'BÜ': 1, 'LhuÖHg': 1, 'LO': 1, 'HHOU': 1, 'VsÜKrbZ': 1, 'MJvhJhfvnd': 1, 'IWc': 1, 'YjpdiGÜTjcJxt': 1, 'YXKjQFVZ': 1, 'ImN': 1, 'BCwOp': 1, 'UWOQ': 1, 'NULÄJlR': 1, 'EAR': 1, 'QORN': 1, 'VyQynz': 1, 'ÄJ': 1, 'WßG': 1, 'OwT': 1, 'ÖNEw': 1, 'OovwRh': 1, 'MsNXN': 1, 'MRV': 1, 'I': 1, 'QvR': 1, 'LwLPßföFriU': 1, 'XYüteü': 1, 'ÖjfYÖRßOgZxwo': 1, 'HHCdBSKöXÜSAAa': 1, 'OBMB': 1, 'StVü': 1, 'GFIöEuvgäBgVHk': 1, 'FM': 1, 'OoPÖQü': 1, 'HEüpQÄJZ': 1, 'ZrRxybrUUo': 1, 'CäA': 1, 'ATd': 1, 'HPsoV': 1, 'EEHgl': 1, 'AöBP': 1, 'ShjUaÄQgVvnöeW': 1, 'TRbv': 1, 'ÜwW': 1, 'LJ': 1, 'ÖÜeZTo': 1, 'ZAÜh': 1, 'CI': 1, 'XIÜ': 1, 'NdWluXptAyikeqr': 1, 'YÖUV': 1, 'IYvädäJu': 1, 'NyäoüÄVOPx': 1, 'AW': 1, 'KmÜPäbyOu': 1, 'JvINWURCfo': 1, 'QÖ': 1, 'DnVvößxO': 1, 'Ftm': 1, 'Iä': 1, 'LiVjHhTTo': 1, 'NaeY': 1, 'AIygD': 1, 'CkWsD': 1, 'FIXär': 1, 'WNmEbmnNt': 1, 'IHiXc': 1, 'ÖVKIQ': 1, 'YbzpJÄbOi': 1, 'AZXm': 1, 'Fp': 1, 'XkHs': 1, 'A': 1, 'QGßRaw': 1, 'FMWÖ': 1, 'YMYMcRbCy': 1, 'BVn': 1, 'QqucOX': 1, 'M': 2, 'JwÄvÜgUiÄmMßTu': 1, 'WkoÜWh': 1, 'GEJMAbMNUKSm': 1, 'ÖKGrhbZ': 1, 'TxywWPOE': 1, 'MQ': 1, 'Zy': 1, 'CBWx': 1, 'AQÖEÄ': 1, 'ZYoIMRT': 1, 'JeßBdDbqVÖGHÜp': 1, 'RR': 1, 'XäüJoxWuJOiU': 1, 'KW': 1, 'BeäFtpJprGYB': 1, 'ZO': 1, 'RÜö': 1, 'YMyx': 1, 'Bheg': 1, 'DAXvEMS': 1, 'RBDhO': 1, 'GIisVk': 1, 'NV': 1, 'ÜPüz': 1, 'ZhGmVjdNÄäc': 1, 'QKuI': 1, 'FrukÜsQSxFeEii': 1, 'YI': 1}
# ---Table---
# 1:	y	6
# 2:	u	5
# 3:	f	4
# 4:	e	4
# 5:	x	4
# 6:	ö	3
# 7:	k	3
# 8:	p	3
# 9:	d	3
# 10:	c	3
# 11:	b	3
# 12:	n	2
# 13:	r	2
# 14:	ä	2
# 15:	v	2
# 16:	o	2
# 17:	t	2
# 18:	g	2
# 19:	UD	2
# 20:	M	2
# 21:	wouP	1
# 22:	duuL	1
# 23:	wjWÄj	1
# 24:	qxtXIpJ	1
# 25:	xGVtÖSaüOysBDb	1
# 26:	oP	1
# 27:	tZQ	1
# 28:	zIIvAy	1
# 29:	ßlFfyLzä	1
# 30:	yqE	1
# 31:	yBDlYf	1
# 32:	öÄX	1
# 33:	ßüp	1
# 34:	mfdW	1
# 35:	äYejßqö	1
# 36:	hH	1
# 37:	cC	1
# 38:	fR	1
# 39:	lÜWzadOiq	1
# 40:	vpvONZ	1
# 41:	ypTKZ	1
# 42:	bß	1
# 43:	qmOM	1
# 44:	äQORsLiPJV	1
# 45:	afADFrGnH	1
# 46:	üaPHJüsx	1
# 47:	ep	1
# 48:	uotONN	1
# 49:	yRkUä	1
# 50:	qc	1
# 51:	eKSAAn	1
# 52:	whuCÜjxpoCca	1
# 53:	äsüN	1
# 54:	euE	1
# 55:	yiPY	1
# 56:	zRuYKw	1
# 57:	övßZü	1
# 58:	q	1
# 59:	fxüFÜEXGKrR	1
# 60:	tnXe	1
# 61:	vSWqSö	1
# 62:	äPiÄJ	1
# 63:	iDDaL	1
# 64:	qnCPHaiTFnyu	1
# 65:	xt	1
# 66:	dc	1
# 67:	üAiFx	1
# 68:	xs	1
# 69:	hütjVjYO	1
# 70:	üM	1
# 71:	jsS	1
# 72:	hxt	1
# 73:	ßüqEoxcfriniZZß	1
# 74:	vTc	1
# 75:	eäTOß	1
# 76:	bCazLWr	1
# 77:	uLfäFäcEPJwnbe	1
# 78:	ltÖwtcXßOioEG	1
# 79:	hIItq	1
# 80:	phLlFwHKäjoaW	1
# 81:	dgqzxCQBcd	1
# 82:	jCükNÖxB	1
# 83:	qÜXc	1
# 84:	ü	1
# 85:	zÄz	1
# 86:	uAMQIo	1
# 87:	fzBöNw	1
# 88:	qCXFd	1
# 89:	stÄtÖÜD	1
# 90:	päeßlr	1
# 91:	nAuFÜvrfeMßwpQSC	1
# 92:	reÄk	1
# 93:	ßFsFS	1
# 94:	pUfppMVJe	1
# 95:	qE	1
# 96:	tjrH	1
# 97:	do	1
# 98:	bSo	1
# 99:	uZVBQrA	1
# 100:	tgp	1
#
# Substantive:  UD M
# ---Slope---
# 	xMedian:  50.5
# 	yMedian:  1.39
# 	Sxy:  -1674.4999999999998
# 	Sxx:  83325.0
# slope:  -0.020096009600960092
# 	-1674.4999999999998/83325.0=-0.020096009600960092
# ---Exponent of Zipf Distribution
# 	xMedian:  50.5
# 	yMedian:  1.39
# 	Sxy:  -1674.4999999999998
# 	Sxx:  83325.0
# slope:  -0.020096009600960092
# 	-1674.4999999999998/83325.0=-0.020096009600960092
# expZipf:  50.76112272320096
# 	1+(1/0.020096009600960092) = 50.76112272320096
# 50.76112272320096
